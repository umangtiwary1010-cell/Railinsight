# %%
import pandas as pd

# %%
df = pd.read_csv("dashboard_data/merged")

# %%
zonal4= df.groupby("station_zone")['delay'].mean().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 zonal4= df.groupby("station_zone")['delay'].mean().sort_values(ascending=False)
#
# NameError: name 'df' is not defined

# %%
df.to_csv('zonal2',index=False)
